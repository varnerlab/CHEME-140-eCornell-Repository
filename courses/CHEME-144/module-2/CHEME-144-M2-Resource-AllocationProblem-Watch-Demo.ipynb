# %% [markdown]
# # Consumer Choice Problems as Linear Programs
# Suppose you are a consumer with a set of products you can purchase, and you want to maximize your utility (satisfaction) from these products while staying within your budget. This is a classic example of a resource allocation task that can be formulated as a primal linear programming problem.
#
# > __Formulation__: Let the set of $n$ products be represented as a collection of objects $X = \left\{x_{i}\right\}_{i=1}^{n}$, where each object $x_{i}$ has a utility score $u_{i}$ and a cost $c_{i}$ per unit object. The consumer has a budget $I$ that they can allocate among these products. Let $x_{i}$ be the number of units of product $i$ that the consumer purchases, the total cost of the products they purchase is given by the expression $\sum_{i=1}^{n} c_{i}\cdot{x}_{i}$.
# Finally, the consumer's utility function is defined as a linear combination of the utility scores of the products they purchase: $U\left(x_{1},\dots,x_{n}\right) = \sum_{i=1}^{n} u_{i}\cdot{x}_{i}$.
#
# Putting all this together, we can formulate the consumer choice problem as the _primal_ linear program:
# $$
# \begin{align*}
# \text{maximize} &\, \sum_{i=1}^{n} u_{i}\;{x}_{i} \\
# \text{subject to}~\sum_{i=1}^{n} c_{i}\;{x}_{i}& \leq I\quad\text{shortcut notation}:\,\left<\mathbf{u},\mathbf{x}\right>\leq{I}\\
# ~x_{i}&\geq{0}\qquad{i=1,2,\dots,n}
# \end{align*}
# $$
# The optimal solution to this problem (if it exists) will give the consumer the optimal number of units of each product to purchase in order to maximize their utility while staying within their budget. In a similar way, we can formulate other resource allocation problems such as production planning, transportation, and network flow as primal linear programming problems.

# %% [markdown]
# ## Alternative formulations: Non-linear Programming Problems
# In what we have shown above, we formulated the resource allocation problem as a maximization problem using a linear objective function, subject to linear constraints. However, suppose the utility function is non-linear, e.g., $U\left(x_{1},\dots,x_{n}\right) = \prod_{i=1}^{n} u_{i}^{x_{i}}$, then the problem becomes a non-linear programming problem.
#
# In this case, we can use techniques such as gradient descent or evolutionary algorithms to find the optimal solution. Alternatively, if the utility function is concave, we can use convex optimization techniques to solve the problem. Let's pose this class of problem as:
#
# Suppose there exists a set of objects $X = \left\{x_{i}\right\}_{i=1}^{n}$, a utility (satisfaction) function $U: X\rightarrow\mathbb{R}$, and $I$ resource units, e.g., money, time, etc, to allocate amongst $x\in{X}$. Then, a _rational agent_ maximizes its utility subject to a budget constraint:
# $$
# \begin{align*}
# \text{maximize}~\mathcal{O}(\mathbf{x}) &= U\left(x_{1},\dots,x_{n}\right) \\
# \text{subject to}~\sum_{i=1}^{n}c_{i}\;{x}_{i} & \leq I\\
# \text{and}~x_{i}&\geq {0}\qquad{i=1,2,\dots,n}
# \end{align*}
# $$
# The terms $c_{i}\geq{0}~\forall{i}$ denote the cost of object $i$, and $x_{i}\geq{0}$ represents the amount of object $i$ purchased, consumed, or otherwise chosen by the agent. If $U: X\rightarrow\mathbb{R}$ is linear in $x_{i}$,
# then the optimal allocation of $X$ is a __linear programming problem__ (like the one we formulated above). Otherwise, the problem is a __non-linear programming problem__.
#
# ___

# %% [markdown]
# ## Solution techniques
# There are many ways we can solve these types of problems, but they depend on whether we are dealing with a linear or non-linear programming problem.
# * __Linear Programming Problems__: We'll explore the Simplex method and Interior Point methods in this module to solve this class of problems. We'll also explore many variants of these problems, including useful applications like selecting your groceries, production planning, transportation, and network flow problems.
# * __Non-linear Programming Problems__: We'll explore the theory behind when these types of non-linear resource problems have solutions, and how to use techniques such as gradient descent and evolutionary algorithms to find the optimal solution.
#
# Really interesting stuff!
# ___
