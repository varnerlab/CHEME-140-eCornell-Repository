# %% [markdown]
# # Activity: Solving the Sugar Choice Problem in Bacteria using an Multiplicative Weights Algorithm
# In thi activity, we weill explore an interesting question in biology, namely, when given a micxture of sugars, which sugar will a Baceteria, such as *E. coli*, choose to metabolize?
#
# > __Learning Objectives:__
# >
# > Three key objectives go here
#
# This is going to be fun, so let's get started!
# ___

# %% [markdown]
# ## Summary
# One direct summary sentence goes here.
#
# > __Key Takeaways:__
# >
# > Three takeaways go here
#
# One direct summary sentence goes here.
# ___
