# %% [markdown]
# # Activity: Implementing a Markov Word Generator
# In this activity, let's construct a program that generates random character sequences of defined length using a discrete Markov chain.
#
# > __Leaning Objectives:__
# >
# > Three learning objectives go here.
