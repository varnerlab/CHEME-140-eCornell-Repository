# %% [markdown]
# # Introduction to Web Services and APIs
# In this module, we will explore the concept of web services and APIs (Application Programming Interfaces). Web services enable different software applications to communicate with each other over the internet, facilitating data exchange and the sharing of functionality. APIs provide a set of rules and protocols for building and interacting with web services.
#
# By the end of this module, you will be able to explain and implement the following concepts:
# * __Web Services__: Understand what web services are, their purpose, and how they enable communication between different software applications over the internet. Web services allow applications to exchange data and functionality, making it easier to integrate systems and share resources.
# * __Common Network Protocols__: Understand the basic network protocols commonly used in web services, such as Hypertext Transfer Protocol (HTTP) and Secure Hypertext Transfer Protocol (HTTPS), as well as other protocols like File Transfer Protocol (FTP) and Simple Mail Transfer Protocol (SMTP). These protocols define how data is transmitted over a network, e.g., the internet, ensuring reliable communication between clients and servers.
# * __Restful Web Services__: Understand the principles of REST (Representational State Transfer) and how to design and implement RESTful web services. RESTful web services use standard HTTP methods (GET, POST, PUT, DELETE) to perform operations on resources identified by URLs. They are stateless, meaning each request from a client contains all the information needed to process the request, and they can return data in various formats, such as JSON or XML.
#
# Networking is an important yet complex topic. We'll not cover all the details of networking. Instead, we'll focus on the concepts most relevant to web services and APIs, providing you with a foundation to understand how web services work and how to build and consume them effectively. So, let's get started!
# ___

# %% [markdown]
# ## Web Services and APIs
# A web service is software that lets machines interact over a network. Application programming interfaces (APIs) are the rules used to access these services.
# * An API specification enables communication between different computer systems and allows clients to request services or data over the Internet. Think of the API as the rules and capabilities of the communication system.
# * A web service has a public-facing API and internal APIs to manage its features and data. Users call the public API methods, which in turn call the private API methods. Data is returned from the public API methods.
# * A web service uses a communication protocol like the Hypertext Transfer Protocol (HTTP) to exchange data over the Internet. It can transfer data in various formats, such as JSON, CSV, and XML, and it can also use other communication protocols.
#
# Let's dig into into the network protocols that enable web services to function effectively.
#
# ___

# %% [markdown]
# <div>
#     <center>
#         <img src="figs/Fig-TopEightNetworkingProtocols-NeedToRedraw.png" width="580"/>
#     </center>
# </div>

# %% [markdown]
# ## Common Network Protocols
#
# These protocols form the foundation of the Internet and web‐service communication by defining how data is exchanged between clients and servers.
#
# * **SMTP (Simple Mail Transfer Protocol):** A text‐based protocol for sending and relaying email between mail servers, specifying how outgoing messages are handed off through the mail‐delivery system.
# * **TCP (Transmission Control Protocol):** A connection‐oriented transport protocol that guarantees reliable, in‐order delivery of a byte stream via handshake, acknowledgments, and retransmissions.
# * **UDP (User Datagram Protocol):** A connectionless transport protocol sending discrete packets (datagrams) with minimal overhead, offering low latency but without guarantees of delivery, ordering, or duplicate protection.
# * **FTP (File Transfer Protocol):** A client-server protocol over TCP for browsing, uploading, and downloading files; supports both anonymous and authenticated sessions.
# * **HTTP/HTTPS (HyperText Transfer Protocol / HTTP Secure):** The application‐layer protocol for fetching web resources, with HTTPS adding TLS encryption for confidentiality and integrity.
#   * **GET:** Retrieves a resource without modifying it.
#   * **POST:** Submits data to create or update a resource (e.g., form data).
#   * **PUT:** Replaces an existing resource or creates it if it does not exist.
#   * **DELETE:** Removes a specified resource.
# * **WebSockets:** A full-duplex, bidirectional protocol over a single TCP connection, enabling low-latency, real-time message exchange (e.g., chat or live feeds).
#
#
# Now that we have a basic understanding of standard network protocols, let's jump into the concept of RESTful web services, a key component of modern web applications.
# ___

# %% [markdown]
# <div>
#     <center>
#         <img src="figs/Fig-RESTFul-Schematic-NeedToRedraw.png" width="580"/>
#     </center>
# </div>

# %% [markdown]
# ## RESTful Web Services
# RESTful web services are a type of web service that follows the principles of REST (Representational State Transfer). REST is an architectural style for creating scalable and stateless web services. It uses standard HTTP methods to operate on resources, which are identified by Uniform Resource Locators (URLs).
# * The REST model functions through a request-response cycle, where a client (such as a web browser or mobile app) sends a request to a server, and the server responds with the requested data or an appropriate status code. Communication typically occurs over HTTPS.
# * The URLs published by the Application Programming Interface (API) are often called _endpoints_. Each endpoint represents a specific resource or group of resources, and the operations on these resources are determined by the HTTP methods used in the requests.
#
# Let's break down the key components of a RESTful web service:
#
# 1. __Client → REST API__: The client (browser, mobile app, etc.) sends an HTTPS request to an API endpoint. The client selects an HTTP method to perform the desired Create/Read/Update/Delete (CRUD) action on a _resource_ (e.g., `/users/42`):
#     - __GET__: retrieve data from the resource, meaning you are requesting information about the resource.
#     - __POST__: create a new resource, meaning you are submitting data to the server to create it.
#     - __PUT__: update an existing resource, meaning you are sending data to modify it.
#     - __DELETE__: delete a specified resource, meaning you are requesting the server to remove it.
#
#     Any payload required for the request is typically encoded in JSON or older formats, such as XML. This can include user authentication, such as identity and permissions data.
#
# 2. __REST API Internals__: Internally, the API layer handles the client request:
#     - **Routing & Controller**: First, it maps the endpoint requested by the client to an appropriate handler function, and routes the request to this function.
#     - **Validation & Business Logic**: The handler function checks the authentication and authorization of the client request, i.e., is this client known and allowed to access the resource? This step also validates client inputs, for example, by checking if the data provided in a POST request is in the correct format and meets the required criteria.
#     - **Serialization**: Converts incoming JSON data into domain objects, and later converts objects back into JSON.
#
#     The internal API logic is implemented by the server developers, who write the code that handles requests and prepares responses. The client doesn’t need to know the details of this implementation; they need to know what to send and what to expect in return.
#
# 3. __REST API → Backend services__: The functions that handle the request may need to access data or perform actions that require communication with lower‐level backend services. They may call other APIs, databases, or microservices to retrieve or manipulate data. This is where the API layer acts as an intermediary between the client and the backend services.
#     - __Backend__: The API layer invokes lower-level backend services (e.g., a database, a microservice, or a message queue).  These calls are typically language- or protocol-specific (e.g., SQL over TCP), rather than HTTP (but not always).
#     - __Data__: The backend returns raw data or status codes to the API layer. This data is not yet in a format that the client will understand (or expects).
#
#     The development of backend services is another interesting topic, with its own set of patterns and debates, such as a collection of (independent) microservices versus a single monolithic service. Let's put that aside (but it's interesting!)
#
# 5. __Server → REST API → Client__: Now, we need to send the data back to the client in the format as promised in the API specification.
# - __Process__: The API server receives the backend’s result, converts it into a JSON response, and attaches an HTTP status code (200, 201, 404, 500, …). Code `200` indicates success, `201` indicates a resource was created, `404` indicates the resource was not found, and `500` indicates an internal server error. The API layer serializes the response data into JSON format, a lightweight data interchange format that is easy for both humans and machines to read and write.
# - __Response__: The API sends the wrapped response back to the client over HTTPS. The response includes the status code and any data that was requested or created. The wrapped response is sent back to the client, and they can do what they want with the data.
#
# ___

# %% [markdown]
# ## Why are RESTful Web Services so Popular?
# RESTful web services have become the de facto standard for building web APIs due to their simplicity, scalability, and ease of use. Here are some key reasons why RESTful web services are so popular:
# - **Statelessness**: Each request from the client to the API carries all the info needed (no session state on the server). Thus, there is no need to maintain session state on the server, which simplifies server design and improves scalability.
# - **Uniform Interface**: A small, well‐known set of verbs (GET/POST/PUT/DELETE) operating on resource URLs. This uniformity makes it easy for developers to understand and use the API without needing to learn complex protocols or conventions.
# - **Layered System**: The client doesn’t need to know whether it’s talking to a monolith or a chain of microservices written in various languages, such as C, Python, Julia, and Java. The client is primarily concerned with what data to send to the API endpoint and the expected response format. This abstraction enables flexibility in the backend architecture, allowing developers to modify or scale components without impacting the client.
#
# ___
